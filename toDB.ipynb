# %%
import geopandas as gpd

# %%
gdf = gpd.read_parquet('Village/TH_Village.parquet')

# %%
gdf
# Out:
#        Vill_  Vill_Id                     Name  Amp_Id  Tam_Name
# 0          1        1          บ้านท่าลานเตียน   10902   ท่าฉนวน  \
# 1          2        4             บ้านหนองสะแก   10902   ท่าฉนวน
# 2          3        5               บ้านหัวยาง   10902   ท่าฉนวน
# 3          4        6             บ้านสะพานหิน   10902   ท่าฉนวน
# 4          5        9           บ้านทุ่งประพาส   10902   ท่าฉนวน
# ...      ...      ...                      ...     ...       ...
# 65208  65209     1781               บ้านควนสระ   66418    ไทรทอง
# 65209  65210     1782              บ้านบางใหญ่   66411  สินเจริญ
# 65210  65211     1783            บ้านบางเหรียง   66411  สินเจริญ
# 65211  65212     1784                บ้านบางพอ   66411  สินเจริญ
# 65212  65213     1785  บ้านต้นมะม่วง (วังหงส์)   66411  สินเจริญ
#
#                   Amp_Name      Prv_Name                    geometry
# 0                  มโนรมย์        ชัยนาท  POINT (100.11985 15.41106)  \
# ...
